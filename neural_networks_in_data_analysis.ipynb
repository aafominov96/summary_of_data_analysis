# %% [markdown]
# # Нейронные сети

# %% [markdown]
# Конспект сделан на основе курса лекций [Вадима Леонардовича Аббакумова](https://github.com/a1ip/Abbakumov) в [Computer Science Center](https://compscicenter.ru/).
#
# Курс находится в открытом доступе на [Youtube-канале CSC](https://www.youtube.com/channel/UC0YHNueF-3Nh3uQT0P4YQZw)
#
# Автор конспекта - [Фоминов Артём Алексеевич](https://github.com/aafominov96)

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
import pandas as pd
from IPython.display import Image
import os
try:
    os.chdir(os.getcwd()+'\\data')
except:
    print('\nТекущая директория:', os.getcwd())

# %% [markdown]
# ## Теоретическое введение

# %% [markdown]
# **Искусственные нейронные сети (ANN)** - широкий класс моделей, которые изначально создавались для моделирования работы мозга. Существует большое множенство видов нейронных сетей, которые [различаются](https://www.asimovinstitute.org/neural-network-zoo/) в зависимости от:
# * решаемой задачи (регрессия/прогнозирование, классификация, кластеризация)
# * архитектуры модели
# * алгоритма обучения сети

# %% [markdown]
# ### Нейронные сети прямого распространения

# %% [markdown]
# #### Структура нейронной сети прямого распространения

# %%
Image('nn3.jpg', width=500)

# %%
Image('nn4.jpg', width=500)

# %%
Image('nn1.jpg', width=500)

# %% [markdown]
# #### Активационные функции

# %% [markdown]
# В теории нейронных сетей **активационной** называется функция, аргументом которой является взвешенная сумма входов искусственного нейрона, а значением — выход нейрона. От вида и формы используемой активационный функции зависит выбор алгоритма обучения сети, а также качество ее обучения на конкретном обучающем множестве. Параметры активационной функции подбираются экспериментально в процессе обучения.

# %%
Image('nn2.jpg', width=500)

# %%
Image('nn3.png', width=500)

# %% [markdown]
# Комбинацией relu-функций мы можем заменить вышепредставленные активационные функции, тем самым сильно упростив вычисления.
